# %% [markdown]
# # Tutorial on Independent Component Analysis
# Mattia Orlandi

# %%
# %load_ext autoreload
# %autoreload 2

import logging

import numpy as np
import torch
from matplotlib import pyplot as plt
from scipy import signal

from ica_tutorial import ica, plotting, preprocessing, utils

logging.basicConfig(level=logging.INFO)

if torch.cuda.is_available():
    device = torch.device("cuda")
    logging.info("Using CUDA version")
else:
    device = torch.device("cpu")
    logging.info("Using CPU version")

SIG_LEN = 4  # s
SIG_FS = 4000  # Hz
SNR = 20  # dB
SEED = 42

t = np.linspace(0, SIG_LEN, SIG_LEN * SIG_FS)
prng = np.random.default_rng(seed=SEED)
# Out:
# INFO:root:Using CUDA version

# %% [markdown]
# ## Outline
# 1. ICA for Instantaneous Mixtures
# 2. ICA for Convolutive Mixtures
# 3. ICA in Non-Stationary Environments

# %% [markdown]
# ## Section 1 - ICA for Instantaneous Mixtures
# Independent Component Analysis (ICA) is a method for separating independent sources from a mixture of signals.
#
# ### Data model
# ICA is based on the following simple instantaneous mixing model:
# $$x_i(t) = \sum_{j=1}^N a_{ij} s_j(t),\;\;\;\;i = 1, ..., M$$
# where
# - $x_i(t)$ is the $i$-th observation;
# - $s_j(t)$ is the $j$-th source;
# - $a_{ij}$ are the coefficients of the mixing matrix;
# - $N$ is the number of sources;
# - $M$ is the number of observations.
#
# The model can be written in matrix form as:
# $$\mathbf{x}(t) = \mathbf{A}\mathbf{s}(t)$$
#
# In ICA, we treat each observation and source signal as a random variable, i.e., the value of a signal at time $t$ is a sample of the corresponding random variable; therefore, we can drop the time index $t$ and write the model as:
# $$\mathbf{x} = \mathbf{A}\mathbf{s}$$
# where $\mathbf{x}$ and $\mathbf{s}$ are, respectively, $M$- and $N$-dimensional random vectors.
#
# ### Assumptions and ambiguities
# ICA aims at recovering the source signal $\mathbf{s}(t)$ from the observations $\mathbf{x}(t)$ only, and is based on the following assumptions:
# 1. The components must be _statistically independent_.
# 2. The components must be _non-gaussian_.
#
# However, it has some ambiguities:
# - the _order_ of the recovered components is arbitrary, since any permutation matrix $\mathbf{P}$ can be substituted in the model giving $\mathbf{x} = \mathbf{A}\mathbf{P}^{-1}\mathbf{P}\mathbf{s}$;
# - the _scale and sign_ of the recovered components is arbitrary, since any scalar multiplier in one of the sources $s_i$ can always be cancelled by dividing the corresponding column $\mathbf{a}_i$ of $\mathbf{A}$ by the same scalar (if, however, we assume that the original components have unitary variance, only the ambiguity of the sign remains).
#
# ### Intuition
# The Central Limit Theorem tells that the distribution of a sum of independent random variables tends towards a gaussian distribution. Thus, the sum of two independent random variables will have a distribution that is closer to gaussian than any of the two original random variables.
#
# In practice, the original components can be estimated by _maximizing their non-gaussianity_.
#
# ### Measures of non-gaussianity
# To use non-gaussianity in ICA, we need a quantitative measure of non-gaussianity of a random variable $y$ (assumed to be zero-mean and to have a variance equal to one).
#
# #### Kurtosis
# The kurtosis of a zero-mean, unit-variance random variable $y$ is defined as:
# $$\text{kurt}(y)=\mathbb{E}[y^4]-3$$
#
# For a gaussian variable, kurtosis is always zero; for non-gaussian variables, it is either positive or negative: distributions characterized by a positive kurtosis (e.g., _sparse_ distributions, namely distributions in which the probability mass is concentrated around the mean and the data-generating process produces occasional values far from the mean) are referred to as _super-gaussian_ or _leptokurtic_, while those characterized by a negative kurtosis are called _sub-gaussian_ or _platykurtic_.
#
# In ICA, we could compute the kurtosis of the component being estimated and follow the direction in which it increases the most (if it's positive) or decreases the most (if it's negative). However, kurtosis can be very sensitive to outliers, thus it's not a very robust measure of non-gaussianity.
#
# #### Negentropy
# The negentropy of a random variable $y$ is defined as:
# $$J(y)=H(y_\text{gauss})-H(y)$$
# where
# - $y_\text{gauss}$ is a gaussian random variable with the same covariance matrix as $y$;
# - $H(\cdot)$ is entropy.
#
# Since a gaussian variable has the largest entropy among all random variables of equal variance, _negentropy is always positive_ and is zero iff the random variable is gaussian.
#
# The exact computation of negentropy is very difficult, and the following approximation is used in practice:
# $$J(y)\propto\left(\mathbb{E}[G(y)]-\mathbb{E}[G(\nu)]\right)^2$$
# where $\nu$ is a gaussian variable of zero mean and unit variance, and $G(\cdot)$ is a non-quadratic function referred to as _contrast function_; common choices for $G$ are:
# - $G(x)=\log\cosh(x)$ (general-purpose);
# - $G(x)=-\exp(-x^2/2)$ for super-gaussian sources;
# - $G(x)=x^4/4$ for sub-gaussian sources;
# - $G(x)=x^3/3$ for sources with high skewness.
#
# ### Pre-processing for ICA
# Before applying ICA algorithms to the data, some pre-processing is useful to simplify the estimation.
#
# #### Centering
# We subtract to vector $\mathbf{x}$ its mean vector to make $\mathbf{x}$ a zero-mean vector; this implies that the vector of original components $\mathbf{s}$ is zero-mean as well.
#
# #### Whitening
# After centering, we whiten the observations $\mathbf{x}$, namely we transform them so that they become uncorrelated and with variance equal to one; in other words, their covariance matrix becomes equal to the identity matrix:
# $$\mathbb{E}[\mathbf{x}\mathbf{x}^\intercal]=\mathbf{I}$$
#
# This procedure is very useful because the new separation matrix to be estimated is orthogonal, thus it has fewer degrees of freedom simplifying ICA.
#
# There are two whitening methods: _PCA_ and _ZCA_.
#
# ##### PCA whitening
# The covariance matrix $\mathbb{E}[\mathbf{x}\mathbf{x}^\intercal]$ is decomposed via eigenvalue decomposition, and the observations are whitened as follows:
# $$\tilde{\mathbf{x}} = \mathbf{D}^{-1/2} \mathbf{E}^\intercal \mathbf{x}$$
# where:
# - $\mathbf{E}$ is the orthogonal matrix of eigenvectors;
# - $\mathbf{D}$ is the diagonal matrix of eigenvalues.
#
# By discarding the less important eigenvalues and eigenvectors, through PCA one can also reduce the dimension of the whitened observations (useful for instance when the number of sources is known, and it's less than the number of observations).
#
# ##### ZCA whitening
# As for PCA, the covariance matrix $\mathbb{E}[\mathbf{x}\mathbf{x}^\intercal]$ is decomposed via eigenvalue decomposition, and the observations are whitened as follows:
# $$\tilde{\mathbf{x}} = \mathbf{E} \mathbf{D}^{-1/2} \mathbf{E}^\intercal \mathbf{x}$$
# namely it's almost equivalent to PCA with an additional rotation.
#
# ZCA does not support dimensionality reduction, but it has the advantage of producing whitened observations that are as close as possible to the original ones.
#
# ### FastICA
# FastICA is a Newton-like algorithm for ICA based on negentropy maximization. To avoid converging to the same source, one can enforce the estimated components to be uncorrelated; two strategies are possible:
# - _deflation_: components are estimated one by one, and are progressively de-correlated using Gram-Schmidt Orthogonalization (light-weight, but estimation errors spread unevenly, namely the first component will be more accurate than the last);
# - _parallel_: components are estimated in parallel, and are de-correlated using symmetric orthogonalization which is based on eigenvalue decomposition (more accurate since estimation errors spread evenly, but more expensive).
#
# If the number of target sources is less than the number of observations, the mixture is said to be _under-complete_; to address this, one can apply two approaches:
# - reduce the dimensionality using PCA;
# - reduce the dimensionality using FastICA itself.

# %% [markdown]
# Let's generate three dummy source signals.

# %%
# Original components
S = np.stack(
    [
        np.sin(2 * np.pi * 1 * t),  # 1Hz
        signal.square(2 * np.pi * 2 * t),  # 2Hz
        signal.sawtooth(2 * np.pi * 4 * t),  # 4Hz
    ]
).T
# Introduce some randomness
S += prng.normal(scale=5e-2, size=S.shape)
# Force unitary variance
S = S / S.std(axis=0)
S = S.astype(np.float32)
n_samples, n_components = S.shape

plotting.plot_signal(
    S,
    fs=SIG_FS,
    title="Original components",
    fig_size=(16, 4),
)

# Compute power spectrum
S_power = utils.power_spectrum(S, fs=SIG_FS)
plotting.plot_signal(
    S_power,
    title="Power spectrum",
    x_label="Frequency [Hz]",
    y_label="Power",
    fig_size=(16, 4),
)

# %% [markdown]
# Let's check that they're uncorrelated.

# %%
plotting.plot_correlation(S, write_annotations=True, fig_size=(9, 6))

# %% [markdown]
# ### Standard system ($N_T = M$)

# %% [markdown]
# #### Noiseless mixture
# Let's generate a noiseless mixture of three observations.

# %%
A = np.asarray(
    [
        [1.0, 1.0, 1.0],
        [0.5, 2.0, 1.0],
        [1.5, 1.0, 2.0],
    ],
    dtype=np.float32,
)  # 3x3 mixing matrix A

X = S @ A.T

plotting.plot_signal(X, fs=SIG_FS, title="Observations", fig_size=(16, 4))

# %% [markdown]
# Let's whiten the mixture, using either ZCA or PCA.

# %%
whiten_model = preprocessing.ZCAWhitening(device=device)
Xw = whiten_model.whiten_training(X)

plotting.plot_correlation(X, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))

# %% [markdown]
# Finally, let's run FastICA.

# %%
# Initial weights
w_init3x3 = torch.from_numpy(prng.standard_normal(size=(3, 3), dtype=np.float32)).to(
    device
)

ica_model = ica.FastICA(
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x3,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 9.511e-03.
# INFO:root:FastICA iteration 2: 4.460e-03.
# INFO:root:FastICA iteration 3: 1.058e-03.
# INFO:root:FastICA iteration 4: 5.466e-04.
# INFO:root:FastICA iteration 5: 1.262e-04.
# INFO:root:FastICA iteration 6: 8.106e-05.
# INFO:root:FastICA converged after 6 iterations, the distance is: 8.106e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# #### Noisy mixture
# Now let's add some noise to the mixture with the given SNR.

# %%
n_channels = X.shape[1]

# Compute signal power and convert to dB
X_avg_power = np.mean(np.square(X), axis=0)
X_avg_db = 10 * np.log10(X_avg_power)
# Compute noise power
noise_avg_db = X_avg_db - SNR
noise_avg_power = 10 ** (noise_avg_db / 10)

# Generate white gaussian noise with given power
noise = np.zeros_like(X)
for i in range(n_channels):  # iterate over channels
    noise[:, i] = prng.standard_normal(n_samples, dtype=np.float32)
    noise[:, i] *= np.sqrt(noise_avg_power[i])
X += noise

plotting.plot_signal(X, fs=SIG_FS, title="Observations", fig_size=(16, 4))

# %% [markdown]
# Let's apply a low-pass filter on the noisy mixture.

# %%
# Filter signal
Xf = preprocessing.lowpass_filter(X, cut=250, fs=SIG_FS)

plotting.plot_signal(Xf, fs=SIG_FS, title="Filtered observations", fig_size=(16, 4))

# %% [markdown]
# Let's whiten the mixture, using either ZCA or PCA.

# %%
whiten_model = preprocessing.ZCAWhitening(device=device)
Xw = whiten_model.whiten_training(Xf)

plotting.plot_correlation(Xf, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))

# %% [markdown]
# Finally, let's run FastICA.

# %%
ica_model = ica.FastICA(
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x3,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 9.866e-03.
# INFO:root:FastICA iteration 2: 3.903e-03.
# INFO:root:FastICA iteration 3: 9.065e-04.
# INFO:root:FastICA iteration 4: 3.831e-04.
# INFO:root:FastICA iteration 5: 8.392e-05.
# INFO:root:FastICA converged after 5 iterations, the distance is: 8.392e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# ### Under-complete system ($N_T < M$)

# %% [markdown]
# #### Noiseless mixture
# Let's generate a noiseless mixture of four observations.

# %%
A = np.asarray(
    [
        [1.0, 1.0, 1.0],
        [0.5, 2.0, 1.0],
        [1.5, 1.0, 2.0],
        [2.0, 1.5, 0.5],
    ],
    dtype=np.float32,
)  # 4x3 mixing matrix A

X = S @ A.T

plotting.plot_signal(X, fs=SIG_FS, title="Observations", fig_size=(16, 4))

# %% [markdown]
# ##### Reducing dimensionality with PCA
# Since the mixture is now under-complete, we reduce the dimensionality of the observations to 3 using PCA.

# %%
whiten_model = preprocessing.PCAWhitening(n_pcs=3, device=device)
Xw = whiten_model.whiten_training(X)

plotting.plot_correlation(X, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))
# Out:
# INFO:root:Reducing dimension of data from 4 to 3.

# %% [markdown]
# Finally, let's run FastICA.

# %%
ica_model = ica.FastICA(
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x3,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 6.834e-02.
# INFO:root:FastICA iteration 2: 1.389e-02.
# INFO:root:FastICA iteration 3: 1.100e-02.
# INFO:root:FastICA iteration 4: 2.589e-03.
# INFO:root:FastICA iteration 5: 1.704e-03.
# INFO:root:FastICA iteration 6: 5.987e-04.
# INFO:root:FastICA iteration 7: 3.681e-04.
# INFO:root:FastICA iteration 8: 1.635e-04.
# INFO:root:FastICA iteration 9: 9.853e-05.
# INFO:root:FastICA converged after 9 iterations, the distance is: 9.853e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# ##### Reducing dimensionality with FastICA
# Alternatively, we can reduce the dimensionality using FastICA itself.
#
# Let's whiten the observations using ZCA.

# %%
whiten_model = preprocessing.ZCAWhitening(device=device)
Xw = whiten_model.whiten_training(X)

plotting.plot_correlation(X, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))

# %% [markdown]
# Noteworthy, the ZCA whitening fails due to the fact that the matrix describing the mixture is not full rank, so it cannot be properly inverted.
#
# Let's run FastICA.

# %%
# Initial weights
w_init3x4 = torch.from_numpy(prng.standard_normal(size=(3, 4), dtype=np.float32)).to(
    device
)

ica_model = ica.FastICA(
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x4,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 8.944e-01.
# INFO:root:FastICA iteration 2: 1.380e-01.
# INFO:root:FastICA iteration 3: 1.980e-02.
# INFO:root:FastICA iteration 4: 3.865e-03.
# INFO:root:FastICA iteration 5: 9.483e-04.
# INFO:root:FastICA iteration 6: 2.634e-04.
# INFO:root:FastICA iteration 7: 7.933e-05.
# INFO:root:FastICA converged after 7 iterations, the distance is: 7.933e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# As expected, FastICA also fails.

# %% [markdown]
# #### Noisy mixture
# Now let's add some noise to the mixture with the given SNR.

# %%
n_channels = X.shape[1]

# Compute signal power and convert to dB
X_avg_power = np.mean(np.square(X), axis=1)
X_avg_db = 10 * np.log10(X_avg_power)
# Compute noise power
noise_avg_db = X_avg_db - SNR
noise_avg_power = 10 ** (noise_avg_db / 10)

# Generate white Gaussian noise with given power
noise = np.zeros_like(X)
for i in range(n_channels):  # iterate over channels
    noise[:, i] = prng.standard_normal(n_samples, dtype=np.float32)
    noise[:, i] *= np.sqrt(noise_avg_power[i])
X += noise

plotting.plot_signal(X, fs=SIG_FS, title="Observations", fig_size=(16, 4))

# %% [markdown]
# Let's apply a low-pass filter on the noisy mixture.

# %%
# Filter signal
Xf = preprocessing.lowpass_filter(X, cut=250, fs=SIG_FS)

plotting.plot_signal(Xf, fs=SIG_FS, title="Filtered observations", fig_size=(16, 4))

# %% [markdown]
# ##### Reducing dimensionality with PCA
# As before, we can reduce the dimensionality of the observations to three using PCA.

# %%
whiten_model = preprocessing.PCAWhitening(n_pcs=3, device=device)
Xw = whiten_model.whiten_training(Xf)

plotting.plot_correlation(Xf, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))
# Out:
# INFO:root:Reducing dimension of data from 4 to 3.

# %% [markdown]
# Finally, let's run FastICA.

# %%
ica_model = ica.FastICA(
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x3,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 5.291e-02.
# INFO:root:FastICA iteration 2: 1.196e-02.
# INFO:root:FastICA iteration 3: 1.046e-02.
# INFO:root:FastICA iteration 4: 6.113e-03.
# INFO:root:FastICA iteration 5: 3.039e-03.
# INFO:root:FastICA iteration 6: 1.141e-03.
# INFO:root:FastICA iteration 7: 6.006e-04.
# INFO:root:FastICA iteration 8: 2.871e-04.
# INFO:root:FastICA iteration 9: 1.616e-04.
# INFO:root:FastICA iteration 10: 8.440e-05.
# INFO:root:FastICA converged after 10 iterations, the distance is: 8.440e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# ##### Reducing dimensionality with FastICA
# Let's try again to reduce the dimensionality via FastICA itself.
#
# Let's whiten the observations using ZCA.

# %%
whiten_model = preprocessing.ZCAWhitening(device=device)
Xw = whiten_model.whiten_training(Xf)

plotting.plot_correlation(Xf, write_annotations=True, fig_size=(9, 6))
plotting.plot_correlation(Xw, write_annotations=True, fig_size=(9, 6))

# %% [markdown]
# This time the ZCA whitening worked, because the matrix is now full rank (thanks to the added noise).
#
# Let's run FastICA.

# %%
ica_model = ica.FastICA(
    n_ics=3,
    whiten_alg="none",
    do_saddle_test=True,
    device=device,
    w_init=w_init3x4,
)
S_rec = ica_model.decompose_training(Xw)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 5.798e-01.
# INFO:root:FastICA iteration 2: 1.735e-01.
# INFO:root:FastICA iteration 3: 2.502e-01.
# INFO:root:FastICA iteration 4: 3.446e-01.
# INFO:root:FastICA iteration 5: 1.297e-01.
# INFO:root:FastICA iteration 6: 1.579e-01.
# INFO:root:FastICA iteration 7: 1.841e-01.
# INFO:root:FastICA iteration 8: 2.084e-01.
# INFO:root:FastICA iteration 9: 2.794e-01.
# INFO:root:FastICA iteration 10: 7.136e-01.
# INFO:root:FastICA iteration 11: 7.758e-02.
# INFO:root:FastICA iteration 12: 1.572e-01.
# INFO:root:FastICA iteration 13: 2.286e-02.
# INFO:root:FastICA iteration 14: 5.355e-02.
# INFO:root:FastICA iteration 15: 7.296e-02.
# INFO:root:FastICA iteration 16: 1.296e-02.
# INFO:root:FastICA iteration 17: 5.413e-04.
# INFO:root:FastICA iteration 18: 4.194e-04.
# INFO:root:FastICA iteration 19: 5.509e-04.
# INFO:root:FastICA iteration 20: 7.692e-04.
# ...

# %% [markdown]
# ### Correlated components
# As a counter-example, let's try to separate a mixture of correlated components.

# %%
# Original components
S = np.stack(
    [
        np.sin(2 * np.pi * 1 * t),  # 1Hz
        signal.square(2 * np.pi * 1 * t),  # 1Hz
        signal.sawtooth(2 * np.pi * 1 * t),  # 1Hz
    ]
).T
# Introduce some randomness
S += prng.normal(scale=5e-2, size=S.shape)
# Force unitary variance
S = S / S.std(axis=0)
S = S.astype(np.float32)
n_samples, n_components = S.shape

plotting.plot_correlation(S, write_annotations=True, fig_size=(9, 6))

# %%
A = np.asarray(
    [
        [1.0, 1.0, 1.0],
        [0.5, 2.0, 1.0],
        [1.5, 1.0, 2.0],
    ],
    dtype=np.float32,
)  # 3x3 mixing matrix A

X = S @ A.T

# Whitening + FastICA
ica_model = ica.FastICA(do_saddle_test=True, device=device)
S_rec = ica_model.decompose_training(X)

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 4))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "logcosh" contrast function.
# INFO:root:FastICA iteration 1: 2.592e-02.
# INFO:root:FastICA iteration 2: 1.196e-02.
# INFO:root:FastICA iteration 3: 4.980e-03.
# INFO:root:FastICA iteration 4: 2.543e-03.
# INFO:root:FastICA iteration 5: 1.225e-03.
# INFO:root:FastICA iteration 6: 6.556e-04.
# INFO:root:FastICA iteration 7: 3.268e-04.
# INFO:root:FastICA iteration 8: 1.810e-04.
# INFO:root:FastICA iteration 9: 9.048e-05.
# INFO:root:FastICA converged after 9 iterations, the distance is: 9.048e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# As expected, the components estimated by FastICA (which forces them to be uncorrelated) do not correspond to the original ones (which are correlated by construction).

# %% [markdown]
# ## Section 2 - ICA for Convolutive Mixtures
# In a real-world scenario (such as in EMG decomposition), mixing processes are not instantaneous: the environment imposes a different impulse response between each source and each receiver pair, resulting in a convolutive mixture:
# $$x_i(t)=\sum_{j=1}^N \sum_{\tau=0}^{L-1} h_{ij}(\tau)s_j(t-\tau)\;\;\;\;i=1,...,M$$
# where:
# - $x_i(t)$ is the $i$-th observation;
# - $s_j(t)$ is the $j$-th source;
# - $h_{ij}(\tau)$ are the coefficients of the mixing Finite Impulse Response (FIR) filter;
# - $L$ is the FIR filter length;
# - $N$ is the number of sources;
# - $M$ is the number of observations.
#
# In matrix form, the equation becomes:
# $$\mathbf{x}(t)=\sum_{\tau=0}^{L-1} \mathbf{H}(\tau)\mathbf{s}(t-\tau)$$
# where:
# - $\mathbf{x}(t)$ comprises the $t$-th samples of the $M$ observations;
# - $\mathbf{s}(t)$ comprises the $t$-th samples of the $M$ sources;
# - $\mathbf{H}(\tau)$ is the $\tau$-th mixing matrix with shape $M \times N$ (assumed _stationary_).
#
# A convolutive mixture with FIR filters such as the one above can be rewritten as an instantaneous mixture by considering an extended vector of $N \cdot L$ sources, comprising the original ones and their $L-1$ delayed replicas. In order to increase the _conditionality_ of the problem, namely the ratio between the number of observations and sources, observations are usually extended, too, by stacking $f_\text{ext}$ delayed replicas:
# $$\bar{\mathbf{x}}(t)=\bar{\mathbf{A}} \bar{\mathbf{s}}(t)$$
# where:
# - $\bar{\mathbf{x}}(t)=[\mathbf{x}(t), \mathbf{x}(t - 1), ..., \mathbf{x}(t - f_\text{ext} + 1)]$ is the extended vector of observations with shape $M \cdot f_\text{ext} \times 1$;
# - $\bar{\mathbf{s}}(t)=[\mathbf{s}(t), \mathbf{s}(t - 1), ..., \mathbf{s}(t - L - f_\text{ext} + 2)]$ is the extended vector of sources with shape $N \cdot (L + f_\text{ext} - 1) \times 1$;
# - $\bar{\mathbf{H}}$ is a $M \cdot f_\text{ext} \times N \cdot (L + f_\text{ext} - 1)$ mixing matrix containing $M \cdot N$ blocks, each representing a $f_\text{ext} \times (L + f_\text{ext} - 1)$ convolution kernel.
#
# Due to the extension step, an additional assumption must be made:
# 1. The components must be _uncorrelated_.
# 2. The components must be _non-gaussian_.
# 3. Each component should _not be auto-correlated_.
#
# If we consider a sparse source, assumptions (2) and (3) are satisfied:
# - sparse sources can be modeled as _leptokurtic_ random variables, thus they're non-gaussian;
# - sparse sources tend not to be auto-correlated.
#
# For simplicity, let's consider a convolutive mixture of a single sparse component and try to recover it (a task referred to as _blind deconvolution_).
#
# Let's generate a sparse source.

# %%
# Generate pulse indexes
ref_period = int(round(15e-3 * SIG_FS))  # refractory period (15ms)

idx = []
last_idx = 0
while True:
    cur_idx = prng.integers(low=last_idx + ref_period, high=last_idx + 2 * ref_period)
    if cur_idx >= n_samples:
        break
    idx.append(cur_idx)
    last_idx = cur_idx
# Generate signal
S = signal.unit_impulse(shape=(SIG_LEN * SIG_FS,), idx=idx)
# Introduce some randomness
S += prng.normal(scale=5e-2, size=S.shape)
# Force unitary variance
S /= S.std()
S = S.astype(np.float32)

plotting.plot_signal(S, fs=SIG_FS, title="Original component", fig_size=(16, 4))

# %% [markdown]
# Let's generate the convolutive mixture by convolving an 80-sample-long (i.e., 20ms) random kernel with the source.

# %%
L = int(round(20e-3 * SIG_FS))  # kernel length
print("Kernel length:", L)

H = prng.standard_normal(size=(L,), dtype=np.float32)
X = np.convolve(S, H, mode="same")

plotting.plot_signal(X, fs=SIG_FS, title="Observation", fig_size=(16, 4))
# Out:
# Kernel length: 80

# %% [markdown]
# Equivalently, one can obtain the observations by:
# - extending the source signal, stacking 80 delayed replicas;
# - do a vector-matrix multiplication between the kernel and the extended sources.

# %%
S_ext = preprocessing.extend_signal(S, f_ext=L)
print("Shape of the vector of extended sources:", S_ext.shape)

X = S_ext @ H.T
plotting.plot_signal(X, fs=SIG_FS, title="Observation", fig_size=(16, 4))
# Out:
# Shape of the vector of extended sources: (15921, 80)

# %% [markdown]
# However, we have a single observation and 80 effective sources. To increase the ratio between the number of observations and sources, we extend the observations (and further extend the sources) by an extension factor $f_\text{ext}$ of 120 samples (i.e., 30ms).

# %%
f_ext = int(round(30e-3 * SIG_FS))  # extension factor
print("Extension factor:", f_ext)

# Extension
S_ext = preprocessing.extend_signal(S, L + f_ext - 1)
H_ext = np.zeros(shape=(f_ext, L + f_ext - 1), dtype=np.float32)
for i in range(f_ext):
    H_ext[i, i : i + L] = H
X_ext = S_ext @ H_ext.T

# Visualize first 10 replicas
plotting.plot_signal(
    X_ext[:, :10],
    fs=SIG_FS,
    title="Delayed observations",
    fig_size=(16, 16),
)
# Out:
# Extension factor: 120

# %% [markdown]
# Let's verify that the components are still uncorrelated.

# %%
plotting.plot_correlation(S_ext, fig_size=(9, 6))

# %% [markdown]
# Now, let's whiten the observations (using either ZCA or PCA) and run FastICA with 20 target components.

# %%
ica_model = ica.FastICA(
    n_ics=20,
    g_name="skewness",
    do_saddle_test=True,
    device=device,
    seed=SEED,
)
S_rec = ica_model.decompose_training(X_ext)
S_rec = torch.nn.functional.pad(S_rec, (0, 0, 0, L + f_ext - 2))  # pad

plotting.plot_signal(S_rec, fs=SIG_FS, title="Recovered ICs", fig_size=(16, 12))
# Out:
# INFO:root:Instantiating FastICA using "symmetric" strategy and "skewness" contrast function.
# INFO:root:FastICA iteration 1: 9.991e-01.
# INFO:root:FastICA iteration 2: 4.465e-01.
# INFO:root:FastICA iteration 3: 1.948e-01.
# INFO:root:FastICA iteration 4: 6.790e-02.
# INFO:root:FastICA iteration 5: 3.740e-02.
# INFO:root:FastICA iteration 6: 3.762e-02.
# INFO:root:FastICA iteration 7: 3.014e-02.
# INFO:root:FastICA iteration 8: 2.993e-02.
# INFO:root:FastICA iteration 9: 2.925e-02.
# INFO:root:FastICA iteration 10: 4.121e-03.
# INFO:root:FastICA iteration 11: 2.706e-05.
# INFO:root:FastICA converged after 11 iterations, the distance is: 2.706e-05.
# INFO:root:Performing saddle test...
# INFO:root:Saddle point test ok.

# %% [markdown]
# To check if the estimated sources are correct, let's extract spikes from both the original source and the estimated ones and compare their number.

# %%
# Extract spikes
S_spikes_t = {"IC0": utils.detect_spikes(S)[0] / SIG_FS}
S_spikes_bin = utils.sparse_to_dense(S_spikes_t, SIG_LEN, SIG_FS)
S_rec_spikes_t = {
    f"IC{i}": utils.detect_spikes(S_rec[:, i])[0] / SIG_FS for i in range(S_rec.size(1))
}
S_rec_spikes_bin = utils.sparse_to_dense(S_rec_spikes_t, SIG_LEN, SIG_FS)

delays = {}
for ic in S_rec_spikes_bin:
    _, delay, tp, fp, fn = utils.check_delayed_pair(
        S_spikes_bin["IC0"].to_numpy(),
        S_rec_spikes_bin[ic].to_numpy(),
        fs=SIG_FS,
        tol_ms=0.5,
        min_perc=0.3,
    )
    delays[ic] = delay / SIG_FS

    # Compute metrics
    roa = tp / (tp + fn + fp)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    print(f"{ic}: delay of {delay} samples.")
    print(f"\tRoA = {roa:.2%}\tPrecision = {precision:.2%}\tRecall = {recall:.2%}")
# Out:
# IC0: delay of -47 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC1: delay of -118 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC2: delay of -70 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC3: delay of -137 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC4: delay of -68 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC5: delay of -147 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC6: delay of -66 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC7: delay of -79 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC8: delay of -82 samples.
# 	RoA = 98.30%	Precision = 100.00%	Recall = 98.30%
# IC9: delay of -62 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC10: delay of -129 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# IC11: delay of -145 samples.
# 	RoA = 98.86%	Precision = 100.00%	Recall = 98.86%
# ...

# %% [markdown]
# The estimated sources are indeed reliable.

# %%
_, axes = plt.subplots(
    nrows=1,
    ncols=2,
    sharex="all",
    sharey="all",
    figsize=(16, 8),
    layout="constrained",
)

axes[0].set_title("Pulses before compensating for delay")
axes[0].scatter(
    x=S_spikes_t["IC0"],
    y=[0] * S_spikes_t["IC0"].size,
    marker="|",
    color="r",
)
axes[1].set_title("Pulses after compensating for delay")
axes[1].scatter(
    x=S_spikes_t["IC0"],
    y=[0] * S_spikes_t["IC0"].size,
    marker="|",
    color="r",
)
for i, ic in enumerate(S_rec_spikes_t.keys()):
    axes[0].scatter(
        x=S_rec_spikes_t[ic],
        y=[i + 1] * S_rec_spikes_t[ic].size,
        marker="|",
        color="k",
    )
    axes[1].scatter(
        x=S_rec_spikes_t[ic] - delays[ic],
        y=[i + 1] * S_rec_spikes_t[ic].size,
        marker="|",
        color="k",
    )
plt.show()

# %% [markdown]
# ## Section 3 - ICA in Non-Stationary Environments
# Up to now, we have assumed that the mixing matrix is stationary.
